# %%
#!python
# Out:
# Python 2.7.12 (default, Nov 19 2016, 06:48:10)
# [GCC 5.4.0 20160609] on linux2
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# KeyboardInterrupt
# >>>

# %% [markdown]
# # Visualizing the data

# %%
import h5py
import numpy as np
import pandas as pd

# %%
GammaEscan = h5py.File("/bigdata/shared/LCD/NewV1/GammaEscan/GammaEscan_1_1.h5", "r")
print "File keys: "
print GammaEscan.keys()
print "\n"

ecal = np.array(GammaEscan["ECAL"], dtype = "float32")
print "ECAL shape"
print ecal.shape
print "\n"
#print "Print ECAL:"
#print ecal
#print "\n"

eFeatNames = np.array(GammaEscan["ECALfeatureNames"], dtype = "float32")
print "ECAL feature names shape:"
print eFeatNames.shape
print "\n"
#print "Print ECAL feature names"
#print eFeatNames
#print "\n"

eFeats = np.array(GammaEscan["ECALfeatures"], dtype = "float32")
print "ECAL features:"
print eFeats.shape
print "\n"
#print "Print ECAL features"
#print eFeats
#print "\n"

hcal = np.array(GammaEscan["HCAL"], dtype = "float32")
print "HCAL shape"
print hcal.shape
print "\n"
#print "Print HCAL"
#print hcal
#print "\n"

hFeatNames = np.array(GammaEscan["HCALfeatureNames"], dtype = "float32")
print "HCAL feature names shape:"
print hFeatNames.shape
print "\n"
#print "Print HCAL feature names"
#print hFeatNames
#print "\n"

hFeats = np.array(GammaEscan["HCALfeatures"], dtype = "float32")
print "HCAL features:"
print hFeats.shape
print "\n"
#print "Print HCAL features"
#print hFeats
#print "\n"

target = np.array(GammaEscan["target"], dtype = "float32")
print "target shape"
print target.shape
print "\n"
#print "Print target:"
#print target
#print "\n"

targetNames = np.array(GammaEscan["targetNames"], dtype = "float32")
print  "target names shape:"
print targetNames.shape
print "\n"
#print "Print target names: "
#print targetNames
#print "\n"
# Out:
# File keys:
# [u'ECAL', u'ECALfeatureNames', u'ECALfeatures', u'HCAL', u'HCALfeatureNames', u'HCALfeatures', u'target', u'targetNames']
#
#
# ECAL shape
# (10000, 25, 25, 25)
#
#
# Print ECAL:
# [[[[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
# ...

# %%
'''
for i in xrange(1,8):
    path = '/bigdata/shared/LCD/kaustuv1993/NewLCD/GammaEscan_%d_MERGED/'%i
    for j in xrange(1,9):
        path += 'GammaEscan_%d_%d.h5'%(i,j)
        #print path
        gammaEscan = h5py.File(path, "r")
        #print gammaEscan.keys()
        path = '/bigdata/shared/LCD/kaustuv1993/NewLCD/GammaEscan_%d_MERGED/'%i
        
ecal = np.array(gammaEscan["ECAL"], dtype = "float32")
print "ECAL shape:"
print ecal.shape
print "\n"
#print ecal
#print "\n"

hcal = np.array(gammaEscan["HCAL"], dtype = "float32")
print "HCAL shape:"
print hcal.shape
print "\n"
#print hcal
#print "\n"

target = np.array(gammaEscan["target"], dtype = "float32")
print "target shape:"
print target.shape
print "\n"
print "print target"
print target
print "\n"

'''
# Out:
# '\nfor i in xrange(1,8):\n    path = \'/bigdata/shared/LCD/kaustuv1993/NewLCD/GammaEscan_%d_MERGED/\'%i\n    for j in xrange(1,9):\n        path += \'GammaEscan_%d_%d.h5\'%(i,j)\n        #print path\n        gammaEscan = h5py.File(path, "r")\n        #print gammaEscan.keys()\n        path = \'/bigdata/shared/LCD/kaustuv1993/NewLCD/GammaEscan_%d_MERGED/\'%i\n        \necal = np.array(gammaEscan["ECAL"], dtype = "float32")\nprint "ECAL shape:"\nprint ecal.shape\nprint "\n"\n#print ecal\n#print "\n"\n\nhcal = np.array(gammaEscan["HCAL"], dtype = "float32")\nprint "HCAL shape:"\nprint hcal.shape\nprint "\n"\n#print hcal\n#print "\n"\n\ntarget = np.array(gammaEscan["target"], dtype = "float32")\nprint "target shape:"\nprint target.shape\nprint "\n"\nprint "print target"\nprint target\nprint "\n"\n\n'

# %%
#import theano 
#print theano.__version__

# %%
#ecal = pd.DataFrame()

# %%
#ecal = f["target"][0:10]

# %%
#ecal.shape()
