# %%
import numpy as np
import os
import sys
import re
import glob
import h5py
import os
#os.environ['KERAS_BACKEND'] = 'theano'
os.environ['KERAS_BACKEND'] = 'tensorflow'
os.environ['CUDA_VISIBLE_DEVICES'] = '4'
from keras.models import Sequential, Model, model_from_json
from keras.layers import Dense, Activation, Input, Dense, Dropout, merge, Reshape, Convolution3D, MaxPooling3D, Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# For Danny's generator:

# %%
if __package__ is None:
    import sys, os
    sys.path.append(os.path.realpath("/data/shared/Software/CMS_Deep_Learning"))
    
from CMS_Deep_Learning.io import gen_from_data, retrieve_data

# %% [markdown]
# Declaring functions for loading and saving models:

# %%
def loadModel(name, weights = False):
    json_file = open('%s.json' % name, 'r')
    loadJson = json_file.read()
    json_file.close()
    
    model = model_from_json(loadJson)
    
    #load weights into new model
    if weights == True:
        model.load_weights('%s.h5' % name)
    #print model.summary()
    
    print("Loaded model from disk")
    return model


def saveModel(model, name = "nn"):
    model_name = name
    model.summary()
    model.save_weights('%s.h5' % model_name, overwrite=True)
    model_json = model.to_json()
    with open("%s.json" % model_name, "w") as json_file:
        json_file.write(model_json)
        
def saveLosses(hist, name="nn"):    
    loss = np.array(hist.history['loss'])
    valoss = np.array(hist.history['val_loss'])
    
    f = h5py.File("%s_losses.h5" % name, "w")
    f.create_dataset('loss', data=loss)
    f.create_dataset('val_loss', data=valoss)
    f.close()

# %% [markdown]
# Loading the model (without weights):

# %%
regression1 = loadModel("regression_1")
regression1.compile(loss= 'mse', optimizer='adam')
# Out:
# Loaded model from disk

# %%
print type(regression1)
# Out:
# <class 'keras.engine.training.Model'>

# %% [markdown]
# Function that plots loss history of the trained model:

# %%
def show_losses( histories ):
    plt.figure(figsize=(5,5))
    #plt.ylim(bottom=0)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training Error by Epoch')
    colors = []
    do_acc = False
    
    for label,loss in histories:
        color = tuple(np.random.random(3))
        colors.append(color)
        l = label
        vl= label + " validation"
        
        if 'acc' in loss.history:
            l += ' (acc %2.4f)' % (loss.history['acc'][-1])
            do_acc = True
            
        if 'val_acc' in loss.history:
            vl += ' (val acc %2.4f)' % (loss.history['val_acc'][-1])
            do_acc = True
        plt.plot(loss.history['loss'], label=l, color=color)
        
        if 'val_loss' in loss.history:
            plt.plot(loss.history['val_loss'], lw=2, ls='dashed', label=vl, color=color)

    plt.legend()
    plt.yscale('log')
    plt.show()
    
    if not do_acc: return
    
    plt.figure(figsize=(5,5))
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    
    for i,(label,loss) in enumerate(histories):
        color = colors[i]
        if 'acc' in loss.history:
            plt.plot(loss.history['acc'], lw=2, label=label+" accuracy", color=color)
            
        if 'val_acc' in loss.history:
            plt.plot(loss.history['val_acc'], lw=2, ls='dashed', label=label+" validation accuracy", color=color)
    
    plt.legend(loc='lower right')
    plt.show()

# %% [markdown]
# Setting up the generator for training:

# %%
# Function to reshape the data, parameter to Danny's generator
def reshapeData(inp):
    (xe, xh), y = inp
    energy = [y[:, 1:]]
    return (xe, xh), energy

# %%
# Defining the directories, which contain the splitted data

train_dir = "/home/vitoriabp/CaloImage_2017/GammaEscan/train"
valid_dir = "/home/vitoriabp/CaloImage_2017/GammaEscan/valid"
test_dir = "/home/vitoriabp/CaloImage_2017/GammaEscan/test"

# %%
## Using Danny's generator

# training set:
train = gen_from_data(train_dir, batch_size=500, data_keys=[["ECAL", "HCAL"], "target"], prep_func=reshapeData)

# validation set:
val = gen_from_data(valid_dir, batch_size=500, data_keys=[["ECAL", "HCAL"], "target"], prep_func=reshapeData)

# testing set:
test = gen_from_data(valid_dir, batch_size=500, data_keys=[["ECAL", "HCAL"], "target"], prep_func=reshapeData)

# %%
# load training data
(xe, xh), yt = next(train)
#xe = ecal input (stands for "x, ecal")
#xh = hcal input (stands for "y, hcal")
#yt = energy target (stands for "y, target")

print(xe.shape)
print(xh.shape)
print(yt.shape)
# Out:
# (500, 25, 25, 25)
# (500, 5, 5, 60)
# (500, 1)

# %% [markdown]
# Before we train the model, we would like to check how many samples there are in an HDF5 file, so that we can set "samples_per_epoch" properly:

# %%
from CMS_Deep_Learning.io import nb_samples_from_h5

print nb_samples_from_h5("/home/vitoriabp/CaloImage_2017/GammaEscan/train/GammaEscan_8_9.h5")
# Out:
# 10000

# %% [markdown]
# Conclusion: Each file has 1000 samples.
# Therefore, we should use samples_per_epoch as the sum of the sizes of all the files in the directory:
# samples_per_epoch = 40*1000
#
# I should write something that automates this and generalizes the number of files for the entire directory, then commit it to Danny.
#
# Now let's train our model:

# %% [markdown]
# # Model training

# %%
hist = regression1.fit_generator(train, samples_per_epoch=40000, 
                           nb_epoch=50,
                           validation_data = val, 
                           nb_val_samples=1000, verbose=1,
                           #validation_split=0.2,
                           callbacks=[EarlyStopping(monitor='val_loss', patience=8, verbose=1, mode='min')
                           , ModelCheckpoint(filepath='/home/vitoriabp/CaloImage_2017/reg1.h5', verbose=0)]
                            )
# Out:
# Epoch 1/50
# 40000/40000 [==============================] - 45s - loss: 36067.0362 - val_loss: 15114.4023
# Epoch 2/50
# 40000/40000 [==============================] - 44s - loss: 7978.8345 - val_loss: 1936.7034
# Epoch 3/50
# 40000/40000 [==============================] - 38s - loss: 1086.5070 - val_loss: 287.9854
# Epoch 4/50
# 40000/40000 [==============================] - 44s - loss: 491.7199 - val_loss: 180.4474
# Epoch 5/50
# 40000/40000 [==============================] - 40s - loss: 413.7796 - val_loss: 65.2573
# Epoch 6/50
# 40000/40000 [==============================] - 52s - loss: 385.2739 - val_loss: 607.4832
# Epoch 7/50
# 40000/40000 [==============================] - 49s - loss: 346.8869 - val_loss: 172.2012
# Epoch 8/50
# 40402/40000 [==============================] - 42s - loss: 276.1761 - val_loss: 104.9301
# ...

# %% [markdown]
# The model was trained, let's take a look at its losses as a function of the epochs.

# %%
show_losses([("model_generator", hist)])

# %% [markdown]
# Now let's see how the models looks after the weighting, and then save it.

# %%
regression1.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 25, 25, 25)    0
# ____________________________________________________________________________________________________
# input_2 (InputLayer)             (None, 5, 5, 60)      0
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 25, 25, 25, 1) 0           input_1[0][0]
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 5, 5, 60, 1)   0           input_2[0][0]
# ____________________________________________________________________________________________________
# convolution3d_1 (Convolution3D)  (None, 22, 22, 22, 3) 195         reshape_1[0][0]
# ...

# %%
saveModel(regression1, "regression1")
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 25, 25, 25)    0
# ____________________________________________________________________________________________________
# input_2 (InputLayer)             (None, 5, 5, 60)      0
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 25, 25, 25, 1) 0           input_1[0][0]
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 5, 5, 60, 1)   0           input_2[0][0]
# ____________________________________________________________________________________________________
# convolution3d_1 (Convolution3D)  (None, 22, 22, 22, 3) 195         reshape_1[0][0]
# ...

# %% [markdown]
# Checkpoint. Here we load back our model if we wish.

# %% [markdown]
# # Checkpoint. Load model.

# %%
regression1 = loadModel("regression_1", weights=True)
regression1.compile(loss= 'mse', optimizer='adam')
# Out:
# Loaded model from disk

# %% [markdown]
# Testing the model:

# %%
# define testing data
(txe, txh), tyt = next(test)
#txe -> ecal input (stands for "test, x, ecal")
#txh -> hcal input (stands for "test, y, hcal")
#tyt -> energy target (stands for "test, y, target")

print(txe.shape)
print(txh.shape)
print(tyt.shape)
# Out:
# (500, 25, 25, 25)
# (500, 5, 5, 60)
# (500, 1)

# %%
pred = regression1.predict([txe, txh])
print pred.shape
# Out:
# (500, 1)

# %%
#print len(pred)

# %%
#print tyt.size
#print pred.size

# %% [markdown]
# Some functions for analyzing the predictions of the model for regression:

# %%
def dif(target, predicted):
    '''
    Returns the difference between the target energy and the predicted energy.

    Parameters:
    target - energy target (label) array (numpy.ndarray)
    predicted - array (numpy.ndarray) of predictions from testing
    
    Returns: Energy difference as numpy.ndarray.
    '''
    dif = target - predicted
    dif = dif.reshape((dif.shape[0],))
    return dif

# %%
def rDif(target, predicted):
    '''
    Returns the relative difference to the target energy of the particle.
    
    Parameters:
    target - energy target (label) array (numpy.ndarray)
    predicted - array (numpy.ndarray) of predictions from testing
    
    Returns: Relative energy difference as numpy.ndarray.
    '''
    dif = target - predicted
    rDif = dif/target
    rDif = rDif.reshape((rDif.shape[0],))
    return rDif

# %%
def plotPredictedXTarget(target, predicted, lim_l=0, lim_r=550):
    '''
    Plots the predicted energy against the target energy.
    
    Parameters:
    target - energy target (label) array (numpy.ndarray)
    predicted - array (numpy.ndarray) of predictions from testing
    lim_l - integer defining the minimum value for both the x and y axes.
    lim_r - integer defining the maximum value for both the x and y axes.
    '''
    
    plt.figure(figsize=(5,5))
    plt.xlabel("Target energy (GeV)")
    plt.ylabel("Predicted energy (GeV)")
    plt.title("Predicted energy against the true energy of the particle, energies between %d and %d GeV" %(lim_l, lim_r))
    
    plt.scatter(target, predicted, color='g', alpha = 0.5)
    
    plt.xlim(lim_l, lim_r)
    plt.ylim(lim_l, lim_r)
    
    plt.legend()
    plt.show()

# %%
#plotPredictedXTarget(tyt, pred)

# %%
import matplotlib.mlab as mlab
from scipy.stats import norm

# %%
from scipy.optimize import curve_fit

# %%
def histEDif(difference, nbins=50, lim=25, lim_l=0, lim_r=550):
    '''
    This function plots histogram of the difference between the predicted energy and the target energy (GeV).
    
    Parameters:
    difference - energy difference as numpy.ndarray. Suggestion: use dif() function here.  
    nbins - number of bins desired for the histogram, as integer.
    lim - integer defining the minimum and maximum values for the x axis.
    lim_l - integer defining the minimum energy value, used in the title of the plot.
    lim_r - integer defining the maximum energy value, used in the title of the plot.
    '''
    
    # the histogram of the data
    n, bins, patches = plt.hist(difference, nbins, normed=1, facecolor='green', alpha=0.75)
    
    # best fit of data
    (mu, sigma) = norm.fit(difference)

    # add a 'best fit' line
    y = mlab.normpdf( bins, mu, sigma)
    l = plt.plot(bins, y, 'r--', linewidth=1)

    plt.xlabel('Difference between the predicted energy and the target energy (GeV)')
    plt.ylabel('Probability')
    plt.title("Energy difference in the regression model, energies between %d and %d GeV" % (lim_l, lim_r))
    
    plt.xlim(-lim, lim)

    plt.show()

# %%
histEDif(dif(tyt, pred), 50)

# %%
'''
def histRelDif(difference, nbins=50, lim=0.2, lim_l=0, lim_r=550):
    histEDif(difference, nbins=nbins, lim=lim, lim_l=lim_l, lim_r=lim_r)
'''
#better create another function for that, so we can change the axes labels and title

# %%
def histRelDif(difference, nbins=50, lim=0.2, lim_l=0, lim_r=550):
    
    '''Plots histogram of the normalized energy difference (%).
    
    Parameters:
    difference - energy difference as numpy.ndarray. Suggestion: use dif() function here.  
    nbins - number of bins desired for the histogram, as integer.
    lim - integer defining the minimum and maximum values for the x axis.
    lim_l - integer defining the minimum energy value, used in the title of the plot.
    lim_r - integer defining the maximum energy value, used in the title of the plot.
    '''
    
    # the histogram of the data
    n, bins, patches = plt.hist(difference, nbins, normed=1, facecolor='green', alpha=0.75, log=True)
    
    mean = np.mean(difference)
    print mean
    
    std = np.std(difference) #standard deviation
    print std
    
    # best fit of data
    (mu, sigma) = norm.fit(difference
                           #, range = (-std,std)
                          )
    print mu, sigma
    
    # add a "best fit" line
    y = mlab.normpdf( bins, mu, sigma) #normal probability density function
    l = plt.plot(bins, y, 'r--', linewidth=1)

    plt.xlim(-lim, lim)
    plt.xlabel('Relative difference between the predicted energy and the target energy (%)')
    plt.ylabel('Probability')
    plt.title("Relative energy difference in the regression model, energies between %d and %d GeV" % (lim_l, lim_r))

    plt.show()

# %%
histRelDif(rDif(tyt, pred), 50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-496-a849ef881eb1> in <module>()
# ----> 1 histRelDif(rDif(tyt, pred), 50)
#
# <ipython-input-15-114ff44558b9> in rDif(target, predicted)
#       9     Returns: Relative energy difference as numpy.ndarray.
#      10     '''
# ---> 11     dif = target - predicted
#      12     rDif = dif/target
#      13     rDif = rDif.reshape((rDif.shape[0],))
#
# ValueError: operands could not be broadcast together with shapes (500,1) (10000,1)

# %%
def plotRelXTarget(target, relative, lim_l=0, lim_r=500):
    '''
    Plots the relative energy difference against the target energy.
    
    Parameters:
    target - energy target (label) array (numpy.ndarray)
    relative - relative energy difference as numpy.ndarray.
    lim_l - (int, double, float) defines the minimum value in the x axis.
    lim_r - (int, double, float) defines the maximum value in the x axis.
    '''
    
    plt.figure(figsize=(5,5))
    plt.xlabel("Target energy (GeV)")
    plt.ylabel("Relative energy difference (%)")
    plt.title("Testing set: Comparing the relative energy difference with the target energy of the particle")
    
    plt.scatter(target, relative, color='g', alpha = 0.5)
    
    plt.xlim(lim_l, lim_r)
    plt.legend()
    plt.show()

# %%
plotRelXTarget(tyt, rDif(tyt, pred))

# %% [markdown]
# Using Danny's input handler to grab all the data from the test set and do the plots.
# In this case we pick the data from only one file, for testing purposes.

# %%
testDir = '/home/vitoriabp/CaloImage_2017/GammaEscan/test/GammaEscan_2_1.h5' # test directory where you get the targets from
mod = '/home/vitoriabp/CaloImage_2017/regression1.json' # model file
w = '/home/vitoriabp/CaloImage_2017/regression1.h5' # weights file

from CMS_Deep_Learning.io import simple_grab

# y is the target energy (label)
y,  = simple_grab(['Y'], data = testDir, label_keys='target')
y = y[:, 1:]
print(y.shape)

# predictions
pred, = simple_grab(['predictions'], data = testDir, label_keys='target', input_keys=['ECAL', 'HCAL'], model = mod, weights = w)
print pred.shape
# Out:
# (10000, 1)
# <type 'numpy.ndarray'>
# (10000, 1)

# %%
plotPredictedXTarget(y, pred)

# %%
histEDif(dif(y, pred), 1000)

# %%
histRelDif(rDif(y, pred), 1000)
# Out:
# 0.0425284192309
# 0.00103630277806 0.0425284192309

# %%
plotRelXTarget(y, rDif(y, pred))

# %% [markdown]
# # Now we pick the data from the entire test directory.

# %%
testDir = '/home/vitoriabp/CaloImage_2017/GammaEscan/test/' # test directory where you get the targets from
mod = '/home/vitoriabp/CaloImage_2017/regression1.json' # model file
w = '/home/vitoriabp/CaloImage_2017/regression1.h5' # weights file

from CMS_Deep_Learning.io import simple_grab

# y is the target energy (label)
all_y,  = simple_grab(['Y'], data = testDir, label_keys='target')
all_y = all_y[:, 1:]
print(all_y.shape)

# predictions
all_y, all_pred, = simple_grab(['predictions'], data = testDir, label_keys='target', input_keys=['ECAL', 'HCAL'], 
                        model = mod, weights = w)
print all_pred.shape
# Out:
# (10000, 1)
# (289499, 1)

# %%
# Energy sum:
s = 0
for t in all_pred:
    s += t

print s

# %%
plotPredictedXTarget(all_y, all_pred)

# %%
histEDif(dif(all_y, all_pred), nbins=500)

# %%
histRelDif(rDif(all_y, all_pred), nbins=350, lim=0.15)

# %%
plotRelXTarget(all_y, rDif(all_y, all_pred))

# %% [markdown]
# As there is so much data for such a big energy range, we can divide the data into bins containing smaller energy ranges, in order to further understand the distributions.

# %%
all_targets = all_y.reshape((289499,))

print all_targets.shape

all_p = all_pred.reshape((289499,))

print all_p.shape
# Out:
# (289499,)
# (289499,)
# [ 167.05883789  364.82778931  453.28274536   13.16115475]

# %% [markdown]
# # bins
#
# Using Danny's function to redistribute the data into bins of smaller energy range.

# %%
from CMS_Deep_Learning.postprocessing.metrics import distribute_to_bins

out, x, y = distribute_to_bins(all_targets, [all_targets, all_p], nb_bins=5, equalBins=True)

# out is trash
# x contains the all_targets data (labels) divided into bins as arrays
# y contains the p_targets data (predictions) divided into bins as arrays

# %%
plotPredictedXTarget(x[0], y[0], 0, 120)

# %%
plotPredictedXTarget(x[1], y[1], 100, 220)

# %%
plotPredictedXTarget(x[2], y[2], 200, 320)

# %%
plotPredictedXTarget(x[3], y[3], 300, 415)

# %%
plotPredictedXTarget(x[4], y[4], 400, 515)

# %% [markdown]
# There is a lot of data, which makes this kind of plot really hard to see, but we can see that the data is scattered as an identity function.
#
# Now let's look at energy difference between the prediction and the target.

# %%
histEDif(dif(x[0], y[0]), nbins=200, lim=20, lim_l=0, lim_r=100)

# %%
histEDif(dif(x[0], y[0]), nbins=450, lim=5, lim_l=0, lim_r=100)

# %%
histEDif(dif(x[0], y[0]), nbins=250, lim=10, lim_l=0, lim_r=100)

# %%
histEDif(dif(x[1], y[1]), nbins=300, lim=10, lim_l=100, lim_r=200)

# %%
histEDif(dif(x[2], y[2]), nbins=500, lim=12, lim_l=200, lim_r=300)

# %%
histEDif(dif(x[3], y[3]), nbins=400, lim=15, lim_l=300, lim_r=400)

# %%
histEDif(dif(x[4], y[4]), nbins=350, lim=20, lim_l=400, lim_r=500)

# %% [markdown]
# We notice that as the energy increases, the energy difference also increases. We have had to increase the number of bins, since the probability for 0 has decreased, and there is more data in the edge values.
#
# Let's compare the relative energ difference for different energy ranges:

# %%
histRelDif(rDif(x[0], y[0]), nbins=250, lim=0.15, lim_l=0, lim_r=100)

# %%
histRelDif(rDif(x[1], y[1]), nbins=250, lim=0.15, lim_l=100, lim_r=200)
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:5991: RuntimeWarning: invalid value encountered in true_divide
#   m = (m.astype(float) / db) / m.sum()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-494-585e028135ea> in <module>()
# ----> 1 histRelDif(rDif(x[1], y[1]), nbins=250, lim=0.15, lim_l=100, lim_r=200)
#
# <ipython-input-493-7e87a3563e8e> in histRelDif(difference, nbins, lim, lim_l, lim_r)
#      12
#      13     # the histogram of the data
# ---> 14     n, bins, patches = plt.hist(difference, bins=np.logspace(0.1, 1.0, 50), normed=1, facecolor='green', alpha=0.75, log=True)
#      15     plt.gca().set_xscale("log")
#      16
#
# ...

# %%
histRelDif(rDif(x[2], y[2]), nbins=250, lim=0.15, lim_l=200, lim_r=300)

# %%
histRelDif(rDif(x[3], y[3]), nbins=250, lim=0.15, lim_l=300, lim_r=400)

# %%
histRelDif(rDif(x[4], y[4]), nbins=250, lim=0.15, lim_l=400, lim_r=500)
# Out:
# 0.00257302959729
# 0.0167275874182
# 0.00257302959729 0.0167275874182

# %% [markdown]
# In these plots we observe the opposite: as the energy grows, the models get better.

# %% [markdown]
# Now we look at the mean and standard deviation against the target energy.

# %%
def plotMeanXEnergy(target, predicted, lim_y=0.14, lim_l=0, lim_r=520, limit=False):
    '''
    Plots the prediction error. 
    (Mean of the distribution of the difference between the target and the predicted energy, divided by the prediction energy, against the target energy).
    
    Parameters:
    target - energy target (label) array (numpy.ndarray)
    predicted - array (numpy.ndarray) of predictions from testing
    lim_y - integer defining the maximum value for the y axis.
    lim_l - integer defining the minimum energy value, x axis.
    lim_r - integer defining the maximum energy value, x axis.
    limit - boolean that defines whether or not to limit the axes.
    '''
    plt.figure(figsize=(5,5))
    plt.xlabel("True energy (GeV)")
    plt.ylabel("Energy difference mean / Predicted energy")
    plt.title("Mean, energies between %d and %d GeV" %(lim_l, lim_r))
    
    plt.scatter(target, np.mean(dif(target, predicted))/predicted, color='g', alpha = 0.5)
    
    if (limit):
        plt.xlim(lim_l, lim_r)
        plt.ylim(0, lim_y)
    
    plt.legend()
    plt.show()

# %%
plotMeanXEnergy(all_y, all_pred, limit=True)

# %%
def plotStdXEnergy(target, predicted, lim_y=2.7, lim_l=0, lim_r=520, limit=False):
    '''
    Plots the prediction deviation depending on the true energy. 
    (Standard deviation of the distribution of the difference between the target and the predicted energy, divided by the predicted energy, against the target energy).
    
    Parameters:
    target - energy target (label) array (numpy.ndarray)
    predicted - array (numpy.ndarray) of predictions from testing
    lim_y - integer defining the maximum value for the y axis.
    lim_l - integer defining the minimum energy value, x axis.
    lim_r - integer defining the maximum energy value, x axis.
    limit - boolean that defines whether or not to limit the axes.
    '''
    plt.figure(figsize=(5,5))
    plt.xlabel("True energy (GeV)")
    plt.ylabel("Standard deviation of the energy difference / Predicted energy")
    plt.title("Standard deviation, energies between %d and %d GeV" % (lim_l, lim_r))
    
    plt.scatter(target, np.std(dif(target, predicted))/predicted, color='g', alpha = 0.5)
    
    if limit:
        plt.xlim(lim_l, lim_r)
        plt.ylim(0, lim_y)
    
    plt.legend()
    plt.show()

# %%
plotStdXEnergy(all_y, all_pred, limit=True)

# %% [markdown]
# Now comparing smaller energy ranges:

# %%
plotMeanXEnergy(x[0], y[0], lim_l=0, lim_r=100)

# %%
plotMeanXEnergy(x[1], y[1], lim_l=100, lim_r=200)

# %%
plotMeanXEnergy(x[2], y[2], lim_y=0.005, lim_l=200, lim_r=300, limit=True)

# %%
plotMeanXEnergy(x[3], y[3], lim_l=300, lim_r=400, limit=True, lim_y=0.005)

# %%
plotMeanXEnergy(x[4], y[4], lim_l=400, limit=True, lim_y=0.005)

# %%
plotStdXEnergy(x[0], y[0], lim_l=0, lim_r=100)

# %%
plotStdXEnergy(x[1], y[1], lim_l=100, lim_r=200, limit=True, lim_y=0.05)

# %%
plotStdXEnergy(x[2], y[2], lim_l=200, lim_r=300, limit=True, lim_y=0.05)

# %%
plotStdXEnergy(x[3], y[3], lim_l=300, lim_r=400, limit=True, lim_y=0.05)

# %%
plotStdXEnergy(x[4], y[4], lim_l=400, limit=True, lim_y=0.05)

# %%
def plotMeans():
    mean1 = np.mean(dif(x[0], y[0]))
    mean2 = np.mean(dif(x[1], y[1]))
    mean3 = np.mean(dif(x[2], y[2]))
    mean4 = np.mean(dif(x[3], y[3]))
    mean5 = np.mean(dif(x[4], y[4]))
    
    plt.figure(figsize=(5,5))
    plt.xlabel("Energy bin")
    plt.ylabel("Energy difference mean (GeV)")
    plt.title("Mean")
    
    plt.scatter(1, mean1, color='green', alpha = 0.5, label='0-100 GeV')
    plt.scatter(2, mean2, color='red', alpha = 0.5, label='100-200 GeV')
    plt.scatter(3, mean3, color='purple', alpha = 0.5, label='200-300 GeV')
    plt.scatter(4, mean4, color='blue', alpha = 0.5, label='300-400 GeV')
    plt.scatter(5, mean5, color='orange', alpha = 0.5, label='400-500 GeV')
    
    plt.legend(loc=2)
    plt.show()
    #plt.savefig("mean_dif.jpg")

# %%
plotMeans()

# %%
def plotStds():
    std1 = np.std(dif(x[0], y[0]))
    std2 = np.std(dif(x[1], y[1]))
    std3 = np.mean(dif(x[2], y[2]))
    std4 = np.std(dif(x[3], y[3]))
    std5 = np.std(dif(x[4], y[4]))
    
    plt.figure(figsize=(5,5))
    plt.xlabel("Energy bin")
    plt.ylabel("Energy difference standard deviation (GeV)")
    plt.title("Standard deviation")
    
    plt.scatter(1, std1, color='green', alpha = 0.5, label='0-100 GeV')
    plt.scatter(2, std2, color='red', alpha = 0.5, label='100-200 GeV')
    plt.scatter(3, std3, color='purple', alpha = 0.5, label='200-300 GeV')
    plt.scatter(4, std4, color='blue', alpha = 0.5, label='300-400 GeV')
    plt.scatter(5, std5, color='orange', alpha = 0.5, label='400-500 GeV')
    
    plt.ylim(0, 8.5)
    
    plt.legend(loc=2)
    plt.show()
    #plt.savefig("std_dif.jpg")

# %%
plotStds()

# %%
def plotRMeans():
    mean1 = np.mean(rDif(x[0], y[0]))
    mean2 = np.mean(rDif(x[1], y[1]))
    mean3 = np.mean(rDif(x[2], y[2]))
    mean4 = np.mean(rDif(x[3], y[3]))
    mean5 = np.mean(rDif(x[4], y[4]))
    
    plt.figure(figsize=(5,5))
    plt.xlabel("Energy bin")
    plt.ylabel("Relative energy difference mean (%)")
    plt.title("Mean")
    
    plt.scatter(1, mean1, color='green', alpha = 0.5, label='0-100 GeV')
    plt.scatter(2, mean2, color='red', alpha = 0.5, label='100-200 GeV')
    plt.scatter(3, mean3, color='purple', alpha = 0.5, label='200-300 GeV')
    plt.scatter(4, mean4, color='blue', alpha = 0.5, label='300-400 GeV')
    plt.scatter(5, mean5, color='orange', alpha = 0.5, label='400-500 GeV')
    
    plt.ylim(-0.003, 0.003)
    
    plt.legend(loc=2)
    plt.show()
    #plt.savefig("mean_rDif.jpg")

# %%
plotRMeans()

# %%
def plotRStds():
    std1 = np.std(rDif(x[0], y[0]))
    std2 = np.std(rDif(x[1], y[1]))
    std3 = np.mean(rDif(x[2], y[2]))
    std4 = np.std(rDif(x[3], y[3]))
    std5 = np.std(rDif(x[4], y[4]))
    
    plt.figure(figsize=(5,5))
    plt.xlabel("Energy bin")
    plt.ylabel("Relative energy difference standard deviation (%)")
    plt.title("Standard deviation")
    
    plt.scatter(1, std1, color='green', alpha = 0.5, label='0-100 GeV')
    plt.scatter(2, std2, color='red', alpha = 0.5, label='100-200 GeV')
    plt.scatter(3, std3, color='purple', alpha = 0.5, label='200-300 GeV')
    plt.scatter(4, std4, color='blue', alpha = 0.5, label='300-400 GeV')
    plt.scatter(5, std5, color='orange', alpha = 0.5, label='400-500 GeV')
    
    plt.ylim(0, 0.1)
    
    plt.legend(loc='best')
    plt.show()
    #plt.savefig("std_rDif.jpg")

# %%
plotRStds()

# %%
print x[2]
# Out:
# [ 206.304536  206.305657  206.307536 ...,  304.31662   304.317431
#   304.320547]

# %%
print y[2]
# Out:
# [ 204.29217529  208.65098572  202.87200928 ...,  303.56665039  301.43618774
#   304.9498291 ]
